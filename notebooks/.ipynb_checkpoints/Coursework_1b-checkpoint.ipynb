# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %% [markdown]
# # Table of Contents
# * [Templates](#Templates)
# * [Task 1](#Task-1)
#     * [Varying number of hidden units](#Varying-number-of-hidden-units.)
#          * [32 hidden units](#32-hidden-units)
#          * [64 hidden units](#64-hidden-units)
#          * [128 hidden units](#128-hidden-units)
#     * [Varying number of hidden layers](#Varying-number-of-layers.)
#         * [2 hidden layers, 128 units](#2-hidden-layers,-128-units)
#         * [3 hidden layers, 128 units](#3-hidden-layers,-128-units)
#     * [Figure 2](#Figure-2)
#     * [Figure 3](#Figure-3)
# * [Task 2](#Task-2)
#     * [EMNIST Experiments](#EMNIST-Experiments)
#         * [Table 3](#Table-3)
#             * [Dropout Experiments](#Dropout-Experiments)
#             * [L1 Penalty Experiments](#L1-Penalty-Experiments)
#             * [L2 Penalty Experiments](#L2-Penalty-Experiments)
#             * [Combined Experiments](#Combined-Experiments)
#         * [Figure 4](#Figure-4)
#             * [Metrics by inclusion rate](#Metrics-by-inclusion-rate)
#             * [Metrics by weight penalty](#Metrics-by-weight-penalty)
#             * [Extra experiments](#Extra-experiments)
# * [Save](#Save)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for num_epochs epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Error')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_xlabel('Accuracy')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102019 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fd5e0158b50>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fd5e0158b50>)

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# %%
#import the DropoutLayer and the penalties
from mlp.layers import DropoutLayer
from mlp.penalties import L1Penalty, L2Penalty

# %%
#Import the network outputs from a npz file
network_outputs = np.load('network_outputs.npz', allow_pickle=True)
hunits32 = network_outputs['hunits32']
hunits64 = network_outputs['hunits64']
hunits128 = network_outputs['hunits128']

hlayers2 = network_outputs['hlayers2']
hlayers3 = network_outputs['hlayers3']

baseline = network_outputs['baseline']

dropout1 = network_outputs['dropout1']
dropout2 = network_outputs['dropout2']
dropout3 = network_outputs['dropout3']

L1pen1 = network_outputs['L1pen1']
L1pen2 = network_outputs['L1pen2']
L1pen3 = network_outputs['L1pen3']

L2pen1 = network_outputs['L2pen1']
L2pen2 = network_outputs['L2pen2']
L2pen3 = network_outputs['L2pen3']

combined1 = network_outputs['combined1']
combined2 = network_outputs['combined2']
combined3 = network_outputs['combined3']
combined4 = network_outputs['combined4']
combined5 = network_outputs['combined5']
combined6 = network_outputs['combined6']

# %% [markdown]
# # Templates

# %% [raw]
# # Setup hyperparameters
# learning_rate = 0.001
# num_epochs = 100
# stats_interval = 1
# input_dim, output_dim, hidden_dim = 784, 47, 128
#
# weights_init = GlorotUniformInit(rng=rng)
# biases_init = ConstantInit(0.)
#
# # Create model with ONE hidden layer
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
# ])
#
# error = CrossEntropySoftmaxError()
# # Use a Adam learning rule
# learning_rule = AdamLearningRule(learning_rate=learning_rate)
#
# # Remember to use notebook=False when you write a script to be run in a terminal
# _ = train_model_and_plot_stats(
#     model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %% [raw]
# # Create model with TWO hidden layers
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # first hidden layer
#     ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # second hidden layer
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
# ])
#
# error = CrossEntropySoftmaxError()
# # Use a Adam learning rule
# learning_rule = AdamLearningRule(learning_rate=learning_rate)
#
# # Remember to use notebook=False when you write a script to be run in a terminal
# _ = train_model_and_plot_stats(
#     model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %% [markdown]
# # Task 1
# ## Varying number of hidden units.
# Initially you will train various 1-hidden layer networks by using either 32, 64 and 128 ReLU hidden units per layer on EMNIST. Make sure you use Adam optimizer with the hyperparameters provided in the template and train each network for 100 epochs. Visualise and discuss how increasing number of hidden units affects the validation performance and whether it worsens or mitigates the overfitting problem.

# %% [markdown]
# ### 32 hidden units

# %%
#setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
hunits32 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 0.9s to complete
#     error(train)=1.23e+00, acc(train)=6.56e-01, error(valid)=1.23e+00, acc(valid)=6.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 0.9s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.13e+00, acc(valid)=6.77e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 0.9s to complete
#     error(train)=1.04e+00, acc(train)=7.06e-01, error(valid)=1.06e+00, acc(valid)=7.03e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 1.0s to complete
#     error(train)=9.74e-01, acc(train)=7.21e-01, error(valid)=9.98e-01, acc(valid)=7.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 1.0s to complete
#     error(train)=9.34e-01, acc(train)=7.32e-01, error(valid)=9.63e-01, acc(valid)=7.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 0.9s to complete
#     error(train)=9.02e-01, acc(train)=7.39e-01, error(valid)=9.31e-01, acc(valid)=7.33e-01
# ...

# %% [raw]
# pickle.dump(hunits32, open( "networks_outputs.p", "wb" ))

# %%
# Print last validation accuracy and calculate generalization gap
print('Validation Accuracy:', '{:.4f}'.format(hunits32[0][-1, hunits32[1]['acc(valid)']]))
print('Generalization gap:', '{:.3f}'.format(np.abs(hunits32[0][-1, hunits32[1]['error(valid)']]-hunits32[0][-1, hunits32[1]['error(train)']])))
# Out:
# Validation Accuracy: 0.7854
# Generalization gap: 0.153

# %% [markdown]
# ### 64 hidden units

# %%
#setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 64

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
hunits64 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 1.2s to complete
#     error(train)=1.06e+00, acc(train)=7.02e-01, error(valid)=1.07e+00, acc(valid)=6.99e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 1.3s to complete
#     error(train)=8.93e-01, acc(train)=7.40e-01, error(valid)=9.19e-01, acc(valid)=7.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 1.4s to complete
#     error(train)=7.89e-01, acc(train)=7.68e-01, error(valid)=8.22e-01, acc(valid)=7.62e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 1.3s to complete
#     error(train)=7.37e-01, acc(train)=7.80e-01, error(valid)=7.76e-01, acc(valid)=7.70e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 1.3s to complete
#     error(train)=6.87e-01, acc(train)=7.92e-01, error(valid)=7.34e-01, acc(valid)=7.77e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 1.3s to complete
#     error(train)=6.46e-01, acc(train)=8.05e-01, error(valid)=7.02e-01, acc(valid)=7.89e-01
# ...

# %%
# Print last validation accuracy and calculate generalization gap
print('Validation Accuracy:', '{:.4f}'.format(hunits64[0][-1, hunits64[1]['acc(valid)']]))
print('Generalization gap:','{:.3f}'.format(np.abs(hunits64[0][-1, hunits64[1]['error(valid)']]-hunits64[0][-1, hunits64[1]['error(train)']])))
# Out:
# Validation Accuracy: 0.8065
# Generalization gap: 0.342

# %% [markdown]
# ### 128 hidden units

# %%
#setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
hunits128 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 2.4s to complete
#     error(train)=9.06e-01, acc(train)=7.37e-01, error(valid)=9.22e-01, acc(valid)=7.31e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 2.8s to complete
#     error(train)=7.00e-01, acc(train)=7.90e-01, error(valid)=7.37e-01, acc(valid)=7.76e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 2.8s to complete
#     error(train)=6.05e-01, acc(train)=8.11e-01, error(valid)=6.57e-01, acc(valid)=7.96e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 2.7s to complete
#     error(train)=5.54e-01, acc(train)=8.24e-01, error(valid)=6.18e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 2.5s to complete
#     error(train)=5.04e-01, acc(train)=8.38e-01, error(valid)=5.81e-01, acc(valid)=8.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 2.5s to complete
#     error(train)=4.81e-01, acc(train)=8.45e-01, error(valid)=5.68e-01, acc(valid)=8.19e-01
# ...

# %%
# Print last validation accuracy and calculate generalization gap
print('Validation Accuracy:', '{:.4f}'.format(hunits128[0][-1, hunits128[1]['acc(valid)']]))
print('Generalization gap:','{:.3f}'.format(np.abs(hunits128[0][-1, hunits128[1]['error(valid)']]-hunits128[0][-1, hunits128[1]['error(train)']])))
# Out:
# Validation Accuracy: 0.8019
# Generalization gap: 0.840

# %% [markdown]
# It looks like clearly increasing the number of hidden units makes the overfitting problem worse.
# *That makes sense, because by increasing the number of hidden units we really increase the number of weights, making the network too flexible.*

# %% [markdown]
# ## Varying number of layers.
# Here you will train various neural networks by using either 1 (previous experiment), 2, 3 hidden layers
# with 128 ReLU hidden units per layer on EMNIST. Make sure you use Adam optimizer with the hyperparameters
# provided in the template and train each network for 100 epochs. Visualise and discuss how increasing number of
# layers affects the validation performance and whether it worsens or mitigates the overfitting problem.

# %% [markdown]
# ### 2 hidden layers, 128 units

# %%
#setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
hlayers2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 2.6s to complete
#     error(train)=7.62e-01, acc(train)=7.69e-01, error(valid)=7.83e-01, acc(valid)=7.63e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 2.6s to complete
#     error(train)=5.88e-01, acc(train)=8.14e-01, error(valid)=6.22e-01, acc(valid)=8.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 2.5s to complete
#     error(train)=5.00e-01, acc(train)=8.36e-01, error(valid)=5.50e-01, acc(valid)=8.23e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 2.6s to complete
#     error(train)=4.71e-01, acc(train)=8.41e-01, error(valid)=5.47e-01, acc(valid)=8.23e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 2.6s to complete
#     error(train)=4.37e-01, acc(train)=8.50e-01, error(valid)=5.23e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 2.6s to complete
#     error(train)=4.00e-01, acc(train)=8.62e-01, error(valid)=5.04e-01, acc(valid)=8.32e-01
# ...

# %%
# Print last validation accuracy and calculate generalization gap
print('Validation Accuracy:', '{:.4f}'.format(hlayers2[0][-1, hlayers2[1]['acc(valid)']]))
print('Generalization gap:','{:.3f}'.format(np.abs(hlayers2[0][-1, hlayers2[1]['error(valid)']]-hlayers2[0][-1, hlayers2[1]['error(train)']])))
# Out:
# Validation Accuracy: 0.8135
# Generalization gap: 1.468

# %% [markdown]
# ### 3 hidden layers, 128 units

# %%
#setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
hlayers3 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.3s to complete
#     error(train)=7.07e-01, acc(train)=7.78e-01, error(valid)=7.31e-01, acc(valid)=7.71e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.3s to complete
#     error(train)=5.65e-01, acc(train)=8.12e-01, error(valid)=6.13e-01, acc(valid)=7.99e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.3s to complete
#     error(train)=4.71e-01, acc(train)=8.43e-01, error(valid)=5.39e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.2s to complete
#     error(train)=4.26e-01, acc(train)=8.54e-01, error(valid)=5.11e-01, acc(valid)=8.29e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.2s to complete
#     error(train)=4.08e-01, acc(train)=8.59e-01, error(valid)=5.14e-01, acc(valid)=8.32e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.2s to complete
#     error(train)=3.81e-01, acc(train)=8.64e-01, error(valid)=5.03e-01, acc(valid)=8.36e-01
# ...

# %%
# Print last validation accuracy and calculate generalization gap
print('Validation Accuracy:', '{:.4f}'.format(hlayers3[0][-1, hlayers3[1]['acc(valid)']]))
print('Generalization gap:','{:.3f}'.format(np.abs(hlayers3[0][-1, hlayers3[1]['error(valid)']]-hlayers3[0][-1, hlayers3[1]['error(train)']])))
# Out:
# Validation Accuracy: 0.8170
# Generalization gap: 1.552

# %% [markdown]
# ## Figure 2
# Experimenting with how to make the adequate figures with matplotlib

# %%
#Accuracy by epoch
fig, ax = plt.subplots()
fig.set_size_inches(8,5)

ax.plot(hunits32[0][:,1], label='width 32(train)')
ax.plot(hunits64[0][:,1], label='width 64(train)')
ax.plot(hunits128[0][:,1], label='width 128(train)')

ax.plot(hunits32[0][:,3], label='width 32(valid)', linestyle='--')
ax.plot(hunits64[0][:,3], label='width 64(valid)', linestyle='--')
ax.plot(hunits128[0][:,3], label='width 128(valid)', linestyle='--')

ax.set_xlabel('Epoch number', fontsize=12)
ax.set_ylabel('Accuracy', fontsize=12)
ax.legend(fontsize=10)
plt.savefig('figures/acc_curve_width.pdf', bbox_inches='tight', pad_inches=0.1)

# %%
#Error by epoch
fig, ax = plt.subplots()
fig.set_size_inches(8,5)

ax.plot(hunits32[0][:,0], label='width 32(train)')
ax.plot(hunits64[0][:,0], label='width 64(train)')
ax.plot(hunits128[0][:,0], label='width 128(train)')

ax.plot(hunits32[0][:,2], label='width 32(valid)', linestyle='--')
ax.plot(hunits64[0][:,2], label='width 64(valid)', linestyle='--')
ax.plot(hunits128[0][:,2], label='width 128(valid)', linestyle='--')

ax.set_xlabel('Epoch number', fontsize=12)
ax.set_ylabel('Error', fontsize=12)
ax.legend(fontsize=10)
plt.savefig('figures/error_curve_width.pdf', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ## Figure 3

# %%
#Accuracy by epoch
fig, ax = plt.subplots()
fig.set_size_inches(8,5)

ax.plot(hunits128[0][:,1], label='depth 1(train)')
ax.plot(hlayers2[0][:,1], label='depth 2(train)')
ax.plot(hlayers3[0][:,1], label='depth 3(train)')

ax.plot(hunits128[0][:,3], label='depth 1(valid)', linestyle='--')
ax.plot(hlayers2[0][:,3], label='depth 2(valid)', linestyle='--')
ax.plot(hlayers3[0][:,3], label='depth 3(valid)', linestyle='--')

ax.set_xlabel('Epoch number', fontsize=12)
ax.set_ylabel('Accuracy', fontsize=12)
ax.legend(fontsize=10)
plt.savefig('figures/acc_curve_depth.pdf', bbox_inches='tight', pad_inches=0.1)

# %%
#Error by epoch
fig, ax = plt.subplots()
fig.set_size_inches(8,5)

ax.plot(hunits128[0][:,0], label='depth 1(train)')
ax.plot(hlayers2[0][:,0], label='depth 2(train)')
ax.plot(hlayers3[0][:,0], label='depth 3(train)')

ax.plot(hunits128[0][:,2], label='depth 1(valid)', linestyle='--')
ax.plot(hlayers2[0][:,2], label='depth 2(valid)', linestyle='--')
ax.plot(hlayers3[0][:,2], label='depth 3(valid)', linestyle='--')

ax.set_xlabel('Epoch number', fontsize=12)
ax.set_ylabel('Error', fontsize=12)
ax.legend(fontsize=10)
plt.savefig('figures/error_curve_depth.pdf', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# # Task 2
# ## Mitigating the problem with Dropout and Weight Penalty
# **Implementing Dropout and Weight Penalty.** Here you will implement DropoutLayer, L1Penalty and
# L2Penalty and test their correctness. Here are the steps to follow:
#
# 1. **Implement the Dropout class in the DropoutLayer of the mlp.layers module.** You need to implement
# fprop and bprop methods for this class. Please note that the solution uses the original dropout formulation
# (i.e. scale the hidden unit activations by p in the final network for compensating missing units). The
# sample distribution to be used for Dropout implementation is a uniform distribution, U(0,1) to pass the
# unit tests.

# %%
#Implemment the fprop method


incl_prob=0.5
idim = 5 #input_dim
bs = 3 #batch_size
inps = np.random.rand(bs, idim) #inputs


def fprop(inputs, stochastic=True):
        """Forward propagates activations through the layer transformation.

        Args:
            inputs: Array of layer inputs of shape (batch_size, input_dim).
            stochastic: Flag allowing different deterministic
                forward-propagation mode in addition to default stochastic
                forward-propagation e.g. for use at test time. If False
                a deterministic forward-propagation transformation
                corresponding to the expected output of the stochastic
                forward-propagation is applied.

        Returns:
            outputs: Array of layer outputs of shape (batch_size, output_dim).
        """
                
        if stochastic:
            dice = np.random.uniform(size=inputs[0].shape)
        else:
            dice = np.zeros(inputs[0].shape)
        booli = (dice < incl_prob)
        outputs = np.multiply(inputs, booli)
        return outputs

fprop(inputs=inps, stochastic=False)
# Out:
# array([[0.09875235, 0.75444207, 0.45887473, 0.06428799, 0.75504114],
#        [0.37337711, 0.67858592, 0.0740063 , 0.84185167, 0.45995945],
#        [0.9426757 , 0.88527523, 0.22429272, 0.50763283, 0.37446387]])

# %%
def bprop(inputs, outputs, grads_wrt_outputs):
        """Back propagates gradients through a layer.

        Given gradients with respect to the outputs of the layer calculates the
        gradients with respect to the layer inputs. This should correspond to
        default stochastic forward-propagation.

        Args:
            inputs: Array of layer inputs of shape (batch_size, input_dim).
            outputs: Array of layer outputs calculated in forward pass of
                shape (batch_size, output_dim).
            grads_wrt_outputs: Array of gradients with respect to the layer
                outputs of shape (batch_size, output_dim).

        Returns:
            Array of gradients with respect to the layer inputs of shape
            (batch_size, input_dim).
        """
        return np.multiply(grads_wrt_outputs, booli)

# %% [markdown]
# 2. **Implement the L1Penalty and L2Penalty class** in the L1Penalty and L2Penalty of the mlp.penalties module. You need to implement `__call__` and `grad` methods for this class. After defining these functions,
# they can be provided as a parameter, weights_penalty, biases_penalty in the AffineLayer class
# while creating the multi-layer neural network.
# 3. **Verify** the correctness of your implementation using the supplied unit tests in
# DropoutandPenalty_tests.ipynb
# 4. Automatically **create test outputs** xxxxxxx_regularization_test_pack.npy, by running the provided
# program scripts/generate_regularization_layer_test_outputs.py which uses your code for
# the previously mentioned layers to run your fprop, bprop, `__call__` and grad methods where necessary
# for each layer on a unique test vector generated using your student ID number.
# To do this part simply go to the scripts folder scripts/ and then run
# python generate_regularization_layer_test_outputs.py --student_id sxxxxxxx replac-
# ing the student id with yours. A file called xxxxxxx_regularization_test_pack.npy will be generated under data which you need to submit with your report.

# %% [markdown]
# ## EMNIST Experiments
# In this section you should modify your baseline network to one that uses one or a
# combination of DropoutLayer with either L1Penalty or L2Penalty and train a model. For the experiments,
# your baseline network should contain 3 hidden layers and 128 hidden units with ReLU activation function. You
# should use the Adam optimizer with a learning rate of 1e−4 as specified in the template.
# Your main aim is to
# 1. investigate whether/how each of these functions addresses the above mentioned problem,
# 2. study the generalization performance of your network when used with one of these functions or a combination of them,
# 3. discover the best possible network configuration, when the only available options to choose from are Dropout and Weight Penalty functions and the hyper-parameters (Dropout inclusion probability and penalty coefficient for the Weight Penalty functions). You should use weight penalty on both weights and biases of your layers. Otherwise, unless explicitly specified, you can leave classes arguments to their default values.
#
# The Dropout inclusion probability is a float value in the range (0,1), e.g. 0.5, chosen manually. Penalty coefficient is also a manually selected float value, e.g. 0.001, usually in the range of 0.1 − 0.00001.**For model selection, you should use validation performance to pick the best model and finally report test performance of the
# best model.**
#
# Ensure that you thoroughly describe how these functions affect performance when used together and separately
# with different hyperparameters in your report, ideally both at the theoretical and empirical level. **Note that
# the expected amount of work in this part is not a brute-force exploration of all possible variations of
# network configurations and hyperparameters but a carefully designed set of experiments that provides
# meaningful analysis and insights.** We have prespecified for what hyperparameter values you should run each
# individual experiment for L1/L2 regularisation and Dropout on **Table 3 of the template.** You will have to identify and argue for a set of 6 different hyperparameter combinations for which to run the combined Dropout and
# L1/L2 experiments. (The number 6 was not picked because there are for example 6 obvious combinations to
# pick or because one could not arguably run more, but rather to limit the amount of experimentation and avoid
# you putting too much time in this. There are many valid combinations of experiments to try, but you should
# motivate your specific selection.)

# %% [markdown]
# ### Table 3

# %% [markdown]
# First, set up the baseline network with 3 hidden layers and 128 hidden units with ReLU activation function, using Adam optimizer and a learning rate of 1e-4.

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
baseline = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.2s to complete
#     error(train)=1.39e+00, acc(train)=6.15e-01, error(valid)=1.39e+00, acc(valid)=6.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 2.8s to complete
#     error(train)=1.11e+00, acc(train)=6.84e-01, error(valid)=1.12e+00, acc(valid)=6.82e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 2.8s to complete
#     error(train)=9.73e-01, acc(train)=7.19e-01, error(valid)=9.87e-01, acc(valid)=7.11e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 2.9s to complete
#     error(train)=8.81e-01, acc(train)=7.43e-01, error(valid)=8.95e-01, acc(valid)=7.38e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.1s to complete
#     error(train)=8.15e-01, acc(train)=7.59e-01, error(valid)=8.33e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.0s to complete
#     error(train)=7.67e-01, acc(train)=7.73e-01, error(valid)=7.86e-01, acc(valid)=7.68e-01
# ...

# %%
# Print last validation accuracy and calculate generalization gap
print('Validation Accuracy:', '{:.3f}'.format(baseline[0][-1, baseline[1]['acc(valid)']]))
print('Generalization gap:','{:.3f}'.format(np.abs(baseline[0][-1, baseline[1]['error(valid)']]-baseline[0][-1, baseline[1]['error(train)']])))
# Out:
# Validation Accuracy: 0.843
# Generalization gap: 0.281

# %% [markdown]
# #### Dropout Experiments

# %% [markdown]
# **Dropout at 0.7**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128
incl_prob=0.7

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
dropout1 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.3s to complete
#     error(train)=2.07e+00, acc(train)=4.31e-01, error(valid)=2.06e+00, acc(valid)=4.35e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.3s to complete
#     error(train)=1.86e+00, acc(train)=5.46e-01, error(valid)=1.86e+00, acc(valid)=5.42e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.3s to complete
#     error(train)=1.76e+00, acc(train)=5.86e-01, error(valid)=1.76e+00, acc(valid)=5.82e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.6s to complete
#     error(train)=1.68e+00, acc(train)=6.18e-01, error(valid)=1.69e+00, acc(valid)=6.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.4s to complete
#     error(train)=1.62e+00, acc(train)=6.42e-01, error(valid)=1.62e+00, acc(valid)=6.40e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.5s to complete
#     error(train)=1.55e+00, acc(train)=6.62e-01, error(valid)=1.55e+00, acc(valid)=6.59e-01
# ...

# %%
print('Validation Accuracy', '{:.4f}'.format(dropout1[0][-1, dropout1[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(dropout1[0][-1, dropout1[1]['error(valid)']]-dropout1[0][-1, dropout1[1]['error(train)']])))
# Out:
# Validation Accuracy 0.8242
# Generalization Gap 0.143

# %% [markdown]
# **Dropout at 0.9**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128
incl_prob=0.9

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
dropout2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.1s to complete
#     error(train)=1.49e+00, acc(train)=5.77e-01, error(valid)=1.49e+00, acc(valid)=5.75e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.1s to complete
#     error(train)=1.22e+00, acc(train)=6.46e-01, error(valid)=1.23e+00, acc(valid)=6.43e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.1s to complete
#     error(train)=1.08e+00, acc(train)=6.84e-01, error(valid)=1.09e+00, acc(valid)=6.82e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.2s to complete
#     error(train)=9.78e-01, acc(train)=7.10e-01, error(valid)=9.90e-01, acc(valid)=7.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.2s to complete
#     error(train)=8.97e-01, acc(train)=7.32e-01, error(valid)=9.14e-01, acc(valid)=7.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.2s to complete
#     error(train)=8.42e-01, acc(train)=7.46e-01, error(valid)=8.59e-01, acc(valid)=7.40e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(dropout2[0][-1, dropout2[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(dropout2[0][-1, dropout2[1]['error(valid)']]-dropout2[0][-1, dropout2[1]['error(train)']])))
# Out:
# Validation Accuracy 0.856
# Generalization Gap 0.168

# %% [markdown]
# **Dropout at 0.95**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128
incl_prob=0.95

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
dropout3 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.1s to complete
#     error(train)=1.39e+00, acc(train)=6.08e-01, error(valid)=1.38e+00, acc(valid)=6.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.8s to complete
#     error(train)=1.14e+00, acc(train)=6.69e-01, error(valid)=1.14e+00, acc(valid)=6.68e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.2s to complete
#     error(train)=9.90e-01, acc(train)=7.07e-01, error(valid)=9.95e-01, acc(valid)=7.06e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.1s to complete
#     error(train)=9.00e-01, acc(train)=7.28e-01, error(valid)=9.09e-01, acc(valid)=7.26e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.2s to complete
#     error(train)=8.21e-01, acc(train)=7.48e-01, error(valid)=8.32e-01, acc(valid)=7.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.2s to complete
#     error(train)=7.63e-01, acc(train)=7.64e-01, error(valid)=7.77e-01, acc(valid)=7.63e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(dropout3[0][-1, dropout3[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(dropout3[0][-1, dropout3[1]['error(valid)']]-dropout3[0][-1, dropout3[1]['error(train)']])))
# Out:
# Validation Accuracy 0.858
# Generalization Gap 0.202

# %% [markdown]
# #### L1 Penalty Experiments

# %% [markdown]
# **L1 penalty at 1e-4**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_pen, biases_pen = L1Penalty(0.0001), L1Penalty(0.0001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
L1pen1 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.8s to complete
#     error(train)=1.37e+00, acc(train)=6.19e-01, error(valid)=1.37e+00, acc(valid)=6.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.1s to complete
#     error(train)=1.12e+00, acc(train)=6.83e-01, error(valid)=1.13e+00, acc(valid)=6.78e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.8s to complete
#     error(train)=9.89e-01, acc(train)=7.17e-01, error(valid)=9.98e-01, acc(valid)=7.15e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.8s to complete
#     error(train)=9.10e-01, acc(train)=7.34e-01, error(valid)=9.22e-01, acc(valid)=7.30e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.8s to complete
#     error(train)=8.37e-01, acc(train)=7.52e-01, error(valid)=8.53e-01, acc(valid)=7.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.8s to complete
#     error(train)=7.92e-01, acc(train)=7.66e-01, error(valid)=8.10e-01, acc(valid)=7.61e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(L1pen1[0][-1, L1pen1[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(L1pen1[0][-1, L1pen1[1]['error(valid)']]-L1pen1[0][-1, L1pen1[1]['error(train)']])))
# Out:
# Validation Accuracy 0.845
# Generalization Gap 0.079

# %% [markdown]
# **L1 penalty at 1e-3**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_pen, biases_pen = L1Penalty(0.001), L1Penalty(0.001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
L1pen2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.8s to complete
#     error(train)=1.73e+00, acc(train)=5.51e-01, error(valid)=1.73e+00, acc(valid)=5.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.7s to complete
#     error(train)=1.57e+00, acc(train)=5.83e-01, error(valid)=1.57e+00, acc(valid)=5.78e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.7s to complete
#     error(train)=1.50e+00, acc(train)=5.99e-01, error(valid)=1.51e+00, acc(valid)=5.91e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.1s to complete
#     error(train)=1.45e+00, acc(train)=6.11e-01, error(valid)=1.46e+00, acc(valid)=6.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.7s to complete
#     error(train)=1.41e+00, acc(train)=6.23e-01, error(valid)=1.41e+00, acc(valid)=6.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.7s to complete
#     error(train)=1.38e+00, acc(train)=6.26e-01, error(valid)=1.39e+00, acc(valid)=6.20e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(L1pen2[0][-1, L1pen2[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(L1pen2[0][-1, L1pen2[1]['error(valid)']]-L1pen2[0][-1, L1pen2[1]['error(train)']])))
# Out:
# Validation Accuracy 0.741
# Generalization Gap 0.008

# %% [markdown]
# **L1 penalty at 1e-1**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_pen, biases_pen = L1Penalty(0.1), L1Penalty(0.1)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
L1pen3 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.0s to complete
#     error(train)=3.85e+00, acc(train)=2.13e-02, error(valid)=3.85e+00, acc(valid)=2.20e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.8s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.8s to complete
#     error(train)=3.85e+00, acc(train)=2.10e-02, error(valid)=3.85e+00, acc(valid)=2.26e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.9s to complete
#     error(train)=3.85e+00, acc(train)=2.15e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.9s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.8s to complete
#     error(train)=3.85e+00, acc(train)=2.15e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(L1pen3[0][-1, L1pen3[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(L1pen3[0][-1, L1pen3[1]['error(valid)']]-L1pen3[0][-1, L1pen3[1]['error(train)']])))
# Out:
# Validation Accuracy 0.023
# Generalization Gap 0.000

# %% [markdown]
# #### L2 Penalty Experiments

# %% [markdown]
# **L2 penalty at 1e-4**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_pen, biases_pen = L2Penalty(0.0001), L2Penalty(0.0001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
L2pen1 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.2s to complete
#     error(train)=1.38e+00, acc(train)=6.19e-01, error(valid)=1.38e+00, acc(valid)=6.15e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.2s to complete
#     error(train)=1.12e+00, acc(train)=6.81e-01, error(valid)=1.13e+00, acc(valid)=6.77e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.1s to complete
#     error(train)=9.81e-01, acc(train)=7.19e-01, error(valid)=1.00e+00, acc(valid)=7.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.3s to complete
#     error(train)=8.85e-01, acc(train)=7.44e-01, error(valid)=9.07e-01, acc(valid)=7.35e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.0s to complete
#     error(train)=8.13e-01, acc(train)=7.63e-01, error(valid)=8.38e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.1s to complete
#     error(train)=7.62e-01, acc(train)=7.75e-01, error(valid)=7.92e-01, acc(valid)=7.65e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(L2pen1[0][-1, L2pen1[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(L2pen1[0][-1, L2pen1[1]['error(valid)']]-L2pen1[0][-1, L2pen1[1]['error(train)']])))
# Out:
# Validation Accuracy 0.846
# Generalization Gap 0.233

# %% [markdown]
# **L2 penalty at 1e-3**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_pen, biases_pen = L2Penalty(0.001), L2Penalty(0.001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
L2pen2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.4s to complete
#     error(train)=1.34e+00, acc(train)=6.27e-01, error(valid)=1.34e+00, acc(valid)=6.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.2s to complete
#     error(train)=1.12e+00, acc(train)=6.82e-01, error(valid)=1.13e+00, acc(valid)=6.81e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.3s to complete
#     error(train)=9.91e-01, acc(train)=7.17e-01, error(valid)=1.00e+00, acc(valid)=7.11e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.5s to complete
#     error(train)=9.08e-01, acc(train)=7.36e-01, error(valid)=9.22e-01, acc(valid)=7.31e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.5s to complete
#     error(train)=8.32e-01, acc(train)=7.58e-01, error(valid)=8.50e-01, acc(valid)=7.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.5s to complete
#     error(train)=7.89e-01, acc(train)=7.67e-01, error(valid)=8.09e-01, acc(valid)=7.60e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(L2pen2[0][-1, L2pen2[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(L2pen2[0][-1, L2pen2[1]['error(valid)']]-L2pen2[0][-1, L2pen2[1]['error(train)']])))
# Out:
# Validation Accuracy 0.849
# Generalization Gap 0.100

# %% [markdown]
# **L2 penalty at 1e-1**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_pen, biases_pen = L2Penalty(0.1), L2Penalty(0.1)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
L2pen3 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.1s to complete
#     error(train)=3.83e+00, acc(train)=7.49e-02, error(valid)=3.83e+00, acc(valid)=7.61e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.6s to complete
#     error(train)=3.85e+00, acc(train)=2.14e-02, error(valid)=3.85e+00, acc(valid)=2.11e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.4s to complete
#     error(train)=3.85e+00, acc(train)=2.14e-02, error(valid)=3.85e+00, acc(valid)=2.11e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.6s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.96e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.6s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.96e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.6s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.96e-02
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(L2pen3[0][-1, L2pen3[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(L2pen3[0][-1, L2pen3[1]['error(valid)']]-L2pen3[0][-1, L2pen3[1]['error(train)']])))
# Out:
# Validation Accuracy 0.020
# Generalization Gap 0.000

# %% [markdown]
# #### Combined Experiments
# Firstly, I'm going to try and combine the hyperparameters that have given the best results (both in terms of validation accuracy and generalization gap) in the **DropoutLayer (0.90), and L1 Penalty (1e-3)**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_prob = 0.9
weights_pen, biases_pen = L1Penalty(0.001), L1Penalty(0.001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
combined1 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.8s to complete
#     error(train)=2.01e+00, acc(train)=4.65e-01, error(valid)=2.01e+00, acc(valid)=4.67e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.7s to complete
#     error(train)=1.74e+00, acc(train)=5.17e-01, error(valid)=1.74e+00, acc(valid)=5.13e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.7s to complete
#     error(train)=1.64e+00, acc(train)=5.41e-01, error(valid)=1.65e+00, acc(valid)=5.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.9s to complete
#     error(train)=1.58e+00, acc(train)=5.57e-01, error(valid)=1.59e+00, acc(valid)=5.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.7s to complete
#     error(train)=1.54e+00, acc(train)=5.65e-01, error(valid)=1.54e+00, acc(valid)=5.63e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.8s to complete
#     error(train)=1.50e+00, acc(train)=5.73e-01, error(valid)=1.51e+00, acc(valid)=5.70e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(combined1[0][-1, combined1[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(combined1[0][-1, combined1[1]['error(valid)']]-combined1[0][-1, combined1[1]['error(train)']])))
# Out:
# Validation Accuracy 0.048
# Generalization Gap 0.006

# %% [markdown]
# Similarly, I'm also going to try and combine the most effective parameters (in acc. and gen. gap) for **DropoutLayer(0.9) and L2 Penalty(1e-3)**

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_prob = 0.9
weights_pen, biases_pen = L2Penalty(0.001), L2Penalty(0.001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
combined2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.9s to complete
#     error(train)=1.53e+00, acc(train)=5.69e-01, error(valid)=1.54e+00, acc(valid)=5.69e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.5s to complete
#     error(train)=1.25e+00, acc(train)=6.39e-01, error(valid)=1.26e+00, acc(valid)=6.38e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.7s to complete
#     error(train)=1.12e+00, acc(train)=6.73e-01, error(valid)=1.13e+00, acc(valid)=6.69e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.6s to complete
#     error(train)=1.01e+00, acc(train)=6.98e-01, error(valid)=1.02e+00, acc(valid)=6.95e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.0s to complete
#     error(train)=9.32e-01, acc(train)=7.20e-01, error(valid)=9.41e-01, acc(valid)=7.17e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.0s to complete
#     error(train)=8.67e-01, acc(train)=7.38e-01, error(valid)=8.77e-01, acc(valid)=7.32e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(combined2[0][-1, combined2[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(combined2[0][-1, combined2[1]['error(valid)']]-combined2[0][-1, combined2[1]['error(train)']])))
# Out:
# Validation Accuracy 0.849
# Generalization Gap 0.060

# %% [markdown]
# Let's try and not penalise the biases maybe. First **L1 Penalty** at 1e-03 just for weights and Dropout at 0.9

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_prob = 0.9
weights_pen, biases_pen = L1Penalty(0.001), None

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
combined3 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.4s to complete
#     error(train)=2.05e+00, acc(train)=4.44e-01, error(valid)=2.04e+00, acc(valid)=4.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.5s to complete
#     error(train)=1.77e+00, acc(train)=5.09e-01, error(valid)=1.78e+00, acc(valid)=5.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.3s to complete
#     error(train)=1.66e+00, acc(train)=5.37e-01, error(valid)=1.66e+00, acc(valid)=5.36e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.0s to complete
#     error(train)=1.58e+00, acc(train)=5.54e-01, error(valid)=1.59e+00, acc(valid)=5.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.6s to complete
#     error(train)=1.54e+00, acc(train)=5.63e-01, error(valid)=1.55e+00, acc(valid)=5.60e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.9s to complete
#     error(train)=1.49e+00, acc(train)=5.74e-01, error(valid)=1.50e+00, acc(valid)=5.69e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(combined3[0][-1, combined3[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(combined3[0][-1, combined3[1]['error(valid)']]-combined3[0][-1, combined3[1]['error(train)']])))
# Out:
# Validation Accuracy 0.709
# Generalization Gap 0.000

# %% [markdown]
# Let's try and not penalise the biases maybe. First **L2 Penalty** at 1e-03 just for weights and Dropout at 0.9

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_prob = 0.9
weights_pen, biases_pen = L2Penalty(0.001), None

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
combined4 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.7s to complete
#     error(train)=1.52e+00, acc(train)=5.72e-01, error(valid)=1.52e+00, acc(valid)=5.74e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.5s to complete
#     error(train)=1.24e+00, acc(train)=6.39e-01, error(valid)=1.25e+00, acc(valid)=6.36e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.4s to complete
#     error(train)=1.11e+00, acc(train)=6.77e-01, error(valid)=1.12e+00, acc(valid)=6.70e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.9s to complete
#     error(train)=1.00e+00, acc(train)=7.05e-01, error(valid)=1.02e+00, acc(valid)=6.98e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.1s to complete
#     error(train)=9.23e-01, acc(train)=7.23e-01, error(valid)=9.39e-01, acc(valid)=7.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.8s to complete
#     error(train)=8.63e-01, acc(train)=7.39e-01, error(valid)=8.81e-01, acc(valid)=7.32e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(combined4[0][-1, combined4[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(combined4[0][-1, combined4[1]['error(valid)']]-combined4[0][-1, combined4[1]['error(train)']])))
# Out:
# Validation Accuracy 0.847
# Generalization Gap 0.063

# %% [markdown]
# Next, let's mix them up. First, use **L1 Penalty for weights** and **L2 Penalty for biases**, both with 1e-03, and keep **DropoutLayer at 0.9**.

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_prob = 0.9
weights_pen, biases_pen = L1Penalty(0.001), L2Penalty(0.001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
combined5 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.1s to complete
#     error(train)=1.97e+00, acc(train)=4.72e-01, error(valid)=1.97e+00, acc(valid)=4.71e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.0s to complete
#     error(train)=1.70e+00, acc(train)=5.25e-01, error(valid)=1.70e+00, acc(valid)=5.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.6s to complete
#     error(train)=1.62e+00, acc(train)=5.41e-01, error(valid)=1.62e+00, acc(valid)=5.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.6s to complete
#     error(train)=1.56e+00, acc(train)=5.56e-01, error(valid)=1.57e+00, acc(valid)=5.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.7s to complete
#     error(train)=1.51e+00, acc(train)=5.68e-01, error(valid)=1.52e+00, acc(valid)=5.62e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.7s to complete
#     error(train)=1.48e+00, acc(train)=5.76e-01, error(valid)=1.49e+00, acc(valid)=5.68e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(combined5[0][-1, combined5[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(combined5[0][-1, combined5[1]['error(valid)']]-combined5[0][-1, combined5[1]['error(train)']])))
# Out:
# Validation Accuracy 0.715
# Generalization Gap 0.008

# %% [markdown]
# Now, use **L2 Penalty for weights** and **L1 Penalty for biases**, both at 1e-03, keeping the **DropoutLayer at 0.9**.

# %%
#setup hyperparameters
learning_rate = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_prob = 0.9
weights_pen, biases_pen = L2Penalty(0.001), L1Penalty(0.001)

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 1
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 2
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_pen, biases_pen), #hidden layer 3
    DropoutLayer(rng, incl_prob),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_pen, biases_pen) #output layer
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
combined6 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.0s to complete
#     error(train)=1.51e+00, acc(train)=5.74e-01, error(valid)=1.50e+00, acc(valid)=5.73e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 5.0s to complete
#     error(train)=1.26e+00, acc(train)=6.35e-01, error(valid)=1.26e+00, acc(valid)=6.30e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.9s to complete
#     error(train)=1.12e+00, acc(train)=6.73e-01, error(valid)=1.13e+00, acc(valid)=6.68e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.4s to complete
#     error(train)=1.02e+00, acc(train)=7.00e-01, error(valid)=1.03e+00, acc(valid)=6.94e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.1s to complete
#     error(train)=9.41e-01, acc(train)=7.20e-01, error(valid)=9.55e-01, acc(valid)=7.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.9s to complete
#     error(train)=8.76e-01, acc(train)=7.38e-01, error(valid)=8.93e-01, acc(valid)=7.33e-01
# ...

# %%
print('Validation Accuracy', '{:.3f}'.format(combined6[0][-1, combined6[1]['acc(valid)']]))
print('Generalization Gap', '{:.3f}'.format(np.abs(combined6[0][-1, combined6[1]['error(valid)']]-combined6[0][-1, combined6[1]['error(train)']])))
# Out:
# Validation Accuracy 0.845
# Generalization Gap 0.065

# %% [markdown]
# ### Figure 4
# #### Metrics by inclusion rate

# %%
#Metrics by inclusion rate
fig, ax = plt.subplots(figsize=(5,5))
fs = 15

dropout_values = [0.7, 0.9, 0.95]
dropout_acc = [dropout1[0][-1, dropout1[1]['acc(valid)']], dropout2[0][-1, dropout2[1]['acc(valid)']], dropout3[0][-1, dropout3[1]['acc(valid)']]]
dropout_gap = ['dropout'+str(i) for i in range(4)[1:]]
dropout_gap = [globals()[x] for x in dropout_gap]
dropout_gap = [np.abs(x[0][-1, x[1]['error(valid)']]-x[0][-1, x[1]['error(train)']]) for x in dropout_gap]

p1, = ax.plot(dropout_values, dropout_acc, label='Val. Acc.')
ax.set_xlabel('Dropout value', fontsize=fs)
ax.set_ylabel('Accuracy', fontsize=fs)

ax2 = ax.twinx()

p2, = ax2.plot(dropout_values, dropout_gap, label='Gap', color='blue')
ax2.set_ylabel('Generalization gap', fontsize=fs)

ax2.legend(fontsize=fs-1, handles=[p1,p2], labels=['Val. Acc', 'Gap'], loc='upper left')
plt.savefig('figures/dropout_plot.pdf', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# #### Metrics by weight penalty

# %%
#Metrics by weight penalty
fig, ax = plt.subplots(figsize=(5,5))
fs = 15

penalty_values = [1e-4, 1e-3, 1e-1]

L1penalty_acc = [L1pen1[0][-1, L1pen1[1]['acc(valid)']], L1pen2[0][-1, L1pen2[1]['acc(valid)']], L1pen3[0][-1, L1pen3[1]['acc(valid)']]]
L2penalty_acc = [L2pen1[0][-1, L2pen1[1]['acc(valid)']], L2pen2[0][-1, L2pen2[1]['acc(valid)']], L2pen3[0][-1, L2pen3[1]['acc(valid)']]]


L1penalty_gap = [globals()['L1pen'+str(i)] for i in range(4)[1:]]
L1penalty_gap = [np.abs(x[0][-1, x[1]['error(valid)']]-x[0][-1, x[1]['error(train)']]) for x in L1penalty_gap]

L2penalty_gap = [globals()['L2pen'+str(i)] for i in range(4)[1:]]
L2penalty_gap = [np.abs(x[0][-1, x[1]['error(valid)']]-x[0][-1, x[1]['error(train)']]) for x in L2penalty_gap]

p1L1, = ax.plot(penalty_values, L1penalty_acc, label='L1 Val. Acc.', color='red')
p1L2, = ax.plot(penalty_values, L2penalty_acc, label='L2 Val. Acc.', color='blue')
ax.set_xlabel('Weight decay value', fontsize=fs)
ax.set_ylabel('Accuracy', fontsize=fs)
ax.set_xscale('log')


ax2 = ax.twinx()

p2L1, = ax2.plot(penalty_values, L1penalty_gap, label='L1 Gap', color='red', linestyle='--')
p2L2, = ax2.plot(penalty_values, L2penalty_gap, label='L2 Gap', color='blue', linestyle='--')
ax2.set_ylabel('Generalization gap', fontsize=fs)

ax2.legend(fontsize=fs-2, handles=[p1L1,p1L2, p2L1, p2L2], labels=['L1 Val. Acc', 'L2 Val. Acc', 'L1 Gap', 'L2 Gap'])
plt.savefig('figures/wd_plot.pdf', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# #### Extra experiments

# %%
labels = ['0.9,\n L1 1e-3', '0.9,\n L2 1e-3', '0.9,\n L1 1e-3 weights', '0.9,\n L2 1e-3 weights', '0.9,\n L1 1e-3 weights,\n L2 1e-3 biases', '0.9,\n L2 1e-3 weights,\n L1 1e-3 biases']
experiments = [globals()['combined'+str(i)] for i in range(7)[1:]]
experiments_acc = [x[0][-1, x[1]['acc(valid)']] for x in experiments]
experiments_gap = [np.abs(x[0][-1, x[1]['error(valid)']]-x[0][-1, x[1]['error(train)']]) for x in experiments]
x_pos = range(len(labels))

fig, ax = plt.subplots(figsize=(5,5))
fs = 15

ax.invert_yaxis()
ax2 = ax.twiny()


p1 = ax.barh(x_pos, experiments_acc, tick_label=labels)
p2 = ax2.barh(x_pos, experiments_gap, tick_label=labels, color='blue', align='edge', height=0.4)
ax2.grid(alpha=0.2)

ax.set_xlabel('Accuracy', fontsize=fs, color='red')
ax2.set_xlabel('Generalization gap', fontsize=fs, labelpad=6, color='blue' )
plt.savefig('figures/extra.pdf', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# # Save

# %%
#Save all the network outputs into an npz file
np.savez('network_outputs.npz', hunits32 = hunits32,
         hunits64 = hunits64,
         hunits128 = hunits128,
         hlayers2 = hlayers2,
         hlayers3 = hlayers2,
         baseline = baseline,
         dropout1 = dropout1,
         dropout2 = dropout2,
         dropout3 = dropout3,
         L1pen1 = L1pen1,
         L1pen2 = L1pen2,
         L1pen3 = L1pen3,
         L2pen1 = L2pen1,
         L2pen2 = L2pen2,
         L2pen3 = L2pen3,
         combined1 = combined1,
         combined2 = combined2,
         combined3 = combined3,
         combined4 = combined4,
         combined5 = combined5,
         combined6 = combined6)
# Out:
# /afs/inf.ed.ac.uk/user/s22/s2259310/miniconda3/envs/mlp/lib/python3.9/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
